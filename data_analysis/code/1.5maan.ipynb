# %%
import pandas as pd
import numpy as np
import re

from sklearn import preprocessing

# %%
data = pd.read_csv('../data/netflix-rotten-tomatoes-metacritic-imdb.csv')

# %%
df = data.copy()
df.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# 3          Series               7.7
# 4           Movie               8.1
#
#                                 Country Availability       Runtime  \
# 0                                           Thailand  < 30 minutes
# 1                                             Canada      1-2 hour
# 2                                             Canada      1-2 hour
# 3                                Belgium,Netherlands  < 30 minutes
# 4  Lithuania,Poland,France,Iceland,Italy,Spain,Gr...      1-2 hour
#
#           Director                      Writer  ... Netflix Release Date  \
# 0  Tomas Alfredson       John Ajvide Lindqvist  ...           2021-03-04
# 1    Coky Giedroyc               Caitlin Moran  ...           2021-03-04
# 2    Brendan Walsh  Brendan Walsh, Daley Nixon  ...           2021-03-04
# 3              NaN                         NaN  ...           2021-03-04
# 4    Stephen Irwin                         NaN  ...           2021-03-04
#
#                          Production House  \
# 0               Canal+, Sandrew Metronome
# 1  Film 4, Monumental Pictures, Lionsgate
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#                              Netflix Link  \
# 0  https://www.netflix.com/watch/81415947
# 1  https://www.netflix.com/watch/81041267
# 2  https://www.netflix.com/watch/81305978
# 3  https://www.netflix.com/watch/81336456
# 4  https://www.netflix.com/watch/81078393
#
#                               IMDb Link  \
# 0  https://www.imdb.com/title/tt1139797
# 1  https://www.imdb.com/title/tt4193072
# 2  https://www.imdb.com/title/tt8945942
# 3  https://www.imdb.com/title/tt6132758
# 4  https://www.imdb.com/title/tt2023611
#
#                                              Summary  IMDb Votes  \
# 0  A med student with a supernatural gift tries t...    205926.0
# 1  When nerdy Johanna moves to London, things get...      2838.0
# 2  Trapped in a frozen car during a blizzard, a p...      1720.0
# 3  Upon moving into a new place, a 20-something r...      1147.0
# 4  Inspired by her moms rebellious past and a con...        63.0
#
#                                                Image  \
# 0  https://occ-0-4708-64.1.nflxso.net/dnm/api/v6/...
# 1  https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 2  https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 3  https://occ-0-1489-1490.1.nflxso.net/dnm/api/v...
# 4  https://occ-0-4039-1500.1.nflxso.net/dnm/api/v...
#
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BOWM4NT...
# 1  https://m.media-amazon.com/images/M/MV5BZGUyN2...
# 2  https://m.media-amazon.com/images/M/MV5BODM2MD...
# 3  https://m.media-amazon.com/images/M/MV5BNWRkMz...
# 4  https://m.media-amazon.com/images/M/MV5BODYyNW...
#
#                                   TMDb Trailer Trailer Site
# 0                                          NaN          NaN
# 1  https://www.youtube.com/watch?v=eIbcxPy4okQ      YouTube
# 2  https://www.youtube.com/watch?v=0RvV7TNUlkQ      YouTube
# 3                                          NaN          NaN
# 4                                          NaN          NaN
#
# [5 rows x 29 columns]

# %%
print(df.shape)
df.isna().sum()
# Out:
# (15480, 29)
# Title                        0
# Genre                     1710
# Tags                        67
# Languages                 1935
# Series or Movie              0
# Hidden Gem Score          2101
# Country Availability        19
# Runtime                      1
# Director                  4708
# Writer                    4330
# Actors                    1925
# View Rating               7024
# IMDb Score                2099
# Rotten Tomatoes Score     9098
# Metacritic Score         11144
# Awards Received           9405
# Awards Nominated For      7819
# Boxoffice                11473
# Release Date              2107
# Netflix Release Date         0
# Production House         10331
# Netflix Link                 0
# IMDb Link                 2303
# Summary                      9
# IMDb Votes                2101
# Image                        0
# Poster                    3638
# TMDb Trailer              8286
# Trailer Site              8286
# dtype: int64

# %%
df['Languages'].unique()
# Out:
# array(['Swedish, Spanish', 'English', 'Turkish', ...,
#        'English, French, Tibetan, Mandarin, Russian, Hindi, Portuguese, Latin, Italian, Spanish',
#        'English, Ibo, Yoruba, Hausa', 'English, Hawaiian, Mandarin'],
#       dtype=object)

# %%
df['Poster'][0]
# Out:
# 'https://m.media-amazon.com/images/M/MV5BOWM4NTY2NTMtZDZlZS00NTgyLWEzZDMtODE3ZGI1MzI3ZmU5XkEyXkFqcGdeQXVyNzI1NzMxNzM@._V1_SX300.jpg'

# %%
df['Image'][0]
# Out:
# 'https://occ-0-4708-64.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABcmgLCxN8dNahdY2kgd1hhcL2a6XrE92x24Bx5h6JFUvH5zMrv6lFWl_aWMt33b6DHvkgsUeDx_8Q1rmopwT3fuF8Rq3S1hrkvFf3uzVv2sb3zrtU-LM1Zy1FfrAKD3nKNyA_RQWrmw.jpg?r=cd0'

# %%
your_list = list()
your_list.append(df.iloc[0,1].replace(' ','').lower().split(','))

# %%
your_list
# Out:
# [['crime', 'drama', 'fantasy', 'horror', 'romance']]

# %%
np.array(your_list).flatten().tolist()
# Out:
# ['crime', 'drama', 'fantasy', 'horror', 'romance']

# %%
df[df['Languages'] == 'Korean'].groupby('Genre').count()
# Out:
#                                              Title  Tags  Languages  \
# Genre
# Action                                           5     5          5
# Action, Adventure, Comedy, Fantasy, History      1     1          1
# Action, Comedy                                   7     7          7
# Action, Comedy, Crime                            4     4          4
# Action, Comedy, Crime, Drama                     2     2          2
# ...                                            ...   ...        ...
# Romance                                          6     6          6
# Sci-Fi, Thriller                                 1     1          1
# Short, Drama                                     1     1          1
# Short, Horror, Mystery, Thriller                 1     1          1
# Thriller                                         5     5          5
#
#                                              Series or Movie  \
# Genre
# Action                                                     5
# Action, Adventure, Comedy, Fantasy, History                1
# Action, Comedy                                             7
# Action, Comedy, Crime                                      4
# Action, Comedy, Crime, Drama                               2
# ...                                                      ...
# Romance                                                    6
# Sci-Fi, Thriller                                           1
# Short, Drama                                               1
# Short, Horror, Mystery, Thriller                           1
# Thriller                                                   5
#
#                                              Hidden Gem Score  \
# Genre
# Action                                                      5
# Action, Adventure, Comedy, Fantasy, History                 1
# Action, Comedy                                              7
# Action, Comedy, Crime                                       3
# Action, Comedy, Crime, Drama                                2
# ...                                                       ...
# Romance                                                     6
# Sci-Fi, Thriller                                            1
# Short, Drama                                                0
# Short, Horror, Mystery, Thriller                            1
# Thriller                                                    5
#
#                                              Country Availability  Runtime  \
# Genre
# Action                                                          5        5
# Action, Adventure, Comedy, Fantasy, History                     1        1
# Action, Comedy                                                  7        7
# Action, Comedy, Crime                                           4        4
# Action, Comedy, Crime, Drama                                    2        2
# ...                                                           ...      ...
# Romance                                                         6        6
# Sci-Fi, Thriller                                                1        1
# Short, Drama                                                    1        1
# Short, Horror, Mystery, Thriller                                1        1
# Thriller                                                        5        5
#
#                                              Director  Writer  Actors  ...  \
# Genre                                                                  ...
# Action                                              5       4       5  ...
# Action, Adventure, Comedy, Fantasy, History         1       1       1  ...
# Action, Comedy                                      7       6       7  ...
# Action, Comedy, Crime                               4       4       4  ...
# Action, Comedy, Crime, Drama                        1       1       2  ...
# ...                                               ...     ...     ...  ...
# Romance                                             0       0       6  ...
# Sci-Fi, Thriller                                    1       1       1  ...
# Short, Drama                                        1       1       1  ...
# Short, Horror, Mystery, Thriller                    0       0       1  ...
# Thriller                                            5       5       5  ...
#
#                                              Netflix Release Date  \
# Genre
# Action                                                          5
# Action, Adventure, Comedy, Fantasy, History                     1
# Action, Comedy                                                  7
# Action, Comedy, Crime                                           4
# Action, Comedy, Crime, Drama                                    2
# ...                                                           ...
# Romance                                                         6
# Sci-Fi, Thriller                                                1
# Short, Drama                                                    1
# Short, Horror, Mystery, Thriller                                1
# Thriller                                                        5
#
#                                              Production House  Netflix Link  \
# Genre
# Action                                                      1             5
# Action, Adventure, Comedy, Fantasy, History                 0             1
# Action, Comedy                                              0             7
# Action, Comedy, Crime                                       1             4
# Action, Comedy, Crime, Drama                                0             2
# ...                                                       ...           ...
# Romance                                                     0             6
# Sci-Fi, Thriller                                            0             1
# Short, Drama                                                0             1
# Short, Horror, Mystery, Thriller                            0             1
# Thriller                                                    2             5
#
#                                              IMDb Link  Summary  IMDb Votes  \
# Genre
# Action                                               5        5           5
# Action, Adventure, Comedy, Fantasy, History          1        1           1
# Action, Comedy                                       7        7           7
# Action, Comedy, Crime                                3        4           3
# Action, Comedy, Crime, Drama                         2        2           2
# ...                                                ...      ...         ...
# Romance                                              4        6           6
# Sci-Fi, Thriller                                     1        1           1
# Short, Drama                                         1        1           0
# Short, Horror, Mystery, Thriller                     1        1           1
# Thriller                                             5        5           5
#
#                                              Image  Poster  TMDb Trailer  \
# Genre
# Action                                           5       5             4
# Action, Adventure, Comedy, Fantasy, History      1       1             1
# Action, Comedy                                   7       7             4
# Action, Comedy, Crime                            4       3             0
# Action, Comedy, Crime, Drama                     2       2             0
# ...                                            ...     ...           ...
# Romance                                          6       3             0
# Sci-Fi, Thriller                                 1       1             1
# Short, Drama                                     1       0             0
# Short, Horror, Mystery, Thriller                 1       1             0
# Thriller                                         5       5             4
#
#                                              Trailer Site
# Genre
# Action                                                  4
# Action, Adventure, Comedy, Fantasy, History             1
# Action, Comedy                                          4
# Action, Comedy, Crime                                   0
# Action, Comedy, Crime, Drama                            0
# ...                                                   ...
# Romance                                                 0
# Sci-Fi, Thriller                                        1
# Short, Drama                                            0
# Short, Horror, Mystery, Thriller                        0
# Thriller                                                4
#
# [151 rows x 28 columns]

# %%
df[df['Title']  == 'Crash Landing on You']
# Out:
#                      Title            Genre  \
# 4295  Crash Landing on You  Comedy, Romance
#
#                                                    Tags Languages  \
# 4295  TV Comedies,Korean TV Shows,Romantic TV Comedi...    Korean
#
#      Series or Movie  Hidden Gem Score  \
# 4295          Series               4.3
#
#                                    Country Availability       Runtime  \
# 4295  Argentina,South Africa,Iceland,Mexico,Thailand...  < 30 minutes
#
#      Director Writer  ... Netflix Release Date Production House  \
# 4295      NaN    NaN  ...           2019-12-14              NaN
#
#                                 Netflix Link  \
# 4295  https://www.netflix.com/watch/81159258
#
#                                   IMDb Link  \
# 4295  https://www.imdb.com/title/tt10850932
#
#                                                 Summary  IMDb Votes  \
# 4295  A paragliding mishap drops a South Korean heir...     12399.0
#
#                                                   Image  \
# 4295  https://occ-0-2851-38.1.nflxso.net/dnm/api/v6/...
#
#                                                  Poster TMDb Trailer  \
# 4295  https://m.media-amazon.com/images/M/MV5BMzRiZW...          NaN
#
#      Trailer Site
# 4295          NaN
#
# [1 rows x 29 columns]

# %%
df[df['Series or Movie'] == 'Series'].count()
# Out:
# Title                    3783
# Genre                    3256
# Tags                     3765
# Languages                3129
# Series or Movie          3783
# Hidden Gem Score         3104
# Country Availability     3779
# Runtime                  3782
# Director                  503
# Writer                   1383
# Actors                   3169
# View Rating              1786
# IMDb Score               3105
# Rotten Tomatoes Score     183
# Metacritic Score           86
# Awards Received          1108
# Awards Nominated For     1462
# Boxoffice                  85
# Release Date             3046
# Netflix Release Date     3783
# Production House          129
# Netflix Link             3783
# IMDb Link                2992
# Summary                  3782
# IMDb Votes               3104
# Image                    3783
# Poster                   2493
# TMDb Trailer                0
# Trailer Site                0
# dtype: int64

# %% [markdown]
# # Genre_List 정규화 with str.split()

# %%
df.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# 3          Series               7.7
# 4           Movie               8.1
#
#                                 Country Availability       Runtime  \
# 0                                           Thailand  < 30 minutes
# 1                                             Canada      1-2 hour
# 2                                             Canada      1-2 hour
# 3                                Belgium,Netherlands  < 30 minutes
# 4  Lithuania,Poland,France,Iceland,Italy,Spain,Gr...      1-2 hour
#
#           Director                      Writer  ... Netflix Release Date  \
# 0  Tomas Alfredson       John Ajvide Lindqvist  ...           2021-03-04
# 1    Coky Giedroyc               Caitlin Moran  ...           2021-03-04
# 2    Brendan Walsh  Brendan Walsh, Daley Nixon  ...           2021-03-04
# 3              NaN                         NaN  ...           2021-03-04
# 4    Stephen Irwin                         NaN  ...           2021-03-04
#
#                          Production House  \
# 0               Canal+, Sandrew Metronome
# 1  Film 4, Monumental Pictures, Lionsgate
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#                              Netflix Link  \
# 0  https://www.netflix.com/watch/81415947
# 1  https://www.netflix.com/watch/81041267
# 2  https://www.netflix.com/watch/81305978
# 3  https://www.netflix.com/watch/81336456
# 4  https://www.netflix.com/watch/81078393
#
#                               IMDb Link  \
# 0  https://www.imdb.com/title/tt1139797
# 1  https://www.imdb.com/title/tt4193072
# 2  https://www.imdb.com/title/tt8945942
# 3  https://www.imdb.com/title/tt6132758
# 4  https://www.imdb.com/title/tt2023611
#
#                                              Summary  IMDb Votes  \
# 0  A med student with a supernatural gift tries t...    205926.0
# 1  When nerdy Johanna moves to London, things get...      2838.0
# 2  Trapped in a frozen car during a blizzard, a p...      1720.0
# 3  Upon moving into a new place, a 20-something r...      1147.0
# 4  Inspired by her moms rebellious past and a con...        63.0
#
#                                                Image  \
# 0  https://occ-0-4708-64.1.nflxso.net/dnm/api/v6/...
# 1  https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 2  https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 3  https://occ-0-1489-1490.1.nflxso.net/dnm/api/v...
# 4  https://occ-0-4039-1500.1.nflxso.net/dnm/api/v...
#
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BOWM4NT...
# 1  https://m.media-amazon.com/images/M/MV5BZGUyN2...
# 2  https://m.media-amazon.com/images/M/MV5BODM2MD...
# 3  https://m.media-amazon.com/images/M/MV5BNWRkMz...
# 4  https://m.media-amazon.com/images/M/MV5BODYyNW...
#
#                                   TMDb Trailer Trailer Site
# 0                                          NaN          NaN
# 1  https://www.youtube.com/watch?v=eIbcxPy4okQ      YouTube
# 2  https://www.youtube.com/watch?v=0RvV7TNUlkQ      YouTube
# 3                                          NaN          NaN
# 4                                          NaN          NaN
#
# [5 rows x 29 columns]

# %%
# df['Genre'][0].split(', ')
df['Genre'].apply(lambda x: x.split(', '))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-a1257fdc4dae> in <module>
#       1 # df['Genre'][0].split(', ')
# ----> 2 df['Genre'].apply(lambda x: x.split(', '))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4106             else:
#    4107                 values = self.astype(object)._values
# -> 4108                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4109
#    4110         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-19-a1257fdc4dae> in <lambda>(x)
#       1 # df['Genre'][0].split(', ')
# ----> 2 df['Genre'].apply(lambda x: x.split(', '))
#
# AttributeError: 'float' object has no attribute 'split'

# %%
# 안됨 ㅋㅋ

genre_list_with_str_df = df['Genre'].apply(lambda x: x.split() in df['Genre'])
genre_list_with_str_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-b004128c82ef> in <module>
#       1 # 안됨 ㅋㅋ
#       2
# ----> 3 genre_list_with_str_df = df['Genre'].apply(lambda x: x.split() in df['Genre'])
#       4 genre_list_with_str_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4106             else:
#    4107                 values = self.astype(object)._values
# -> 4108                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4109
#    4110         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-10-b004128c82ef> in <lambda>(x)
#       1 # 안됨 ㅋㅋ
#       2
# ----> 3 genre_list_with_str_df = df['Genre'].apply(lambda x: x.split() in df['Genre'])
#       4 genre_list_with_str_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __contains__(self, key)
#    1836     def __contains__(self, key) -> bool_t:
#    1837         """True if the key is in the info axis"""
# -> 1838         return key in self._info_axis
#    1839
#    1840     @property
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in __contains__(self, key)
#     333
#     334     def __contains__(self, key: Any) -> bool:
# --> 335         hash(key)
#     336         try:
#     337             key = ensure_python_int(key)
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# # Genre_List 정규화
# - 띄어쓰기 없애기
# - lower

# %%
genre_before_rg = df['Genre']
reg_genre = []

for i in range(len(genre_before_rg)):
    try:
        target = df.iloc[i,1].replace(' ','').lower().split(',')
        reg_genre.append(target)

#         print(target)
    except:
        reg_genre.append(None)

# %%
genre_list_df = df.copy()

# %%
genre_list_df.insert(2, 'Genre_List', reg_genre)

# %%
genre_list_df.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                  Genre_List  \
# 0  [crime, drama, fantasy, horror, romance]
# 1                                  [comedy]
# 2                         [drama, thriller]
# 3                                   [drama]
# 4                 [animation, short, drama]
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# 3          Series               7.7
# 4           Movie               8.1
#
#                                 Country Availability       Runtime  \
# 0                                           Thailand  < 30 minutes
# 1                                             Canada      1-2 hour
# 2                                             Canada      1-2 hour
# 3                                Belgium,Netherlands  < 30 minutes
# 4  Lithuania,Poland,France,Iceland,Italy,Spain,Gr...      1-2 hour
#
#           Director  ... Netflix Release Date  \
# 0  Tomas Alfredson  ...           2021-03-04
# 1    Coky Giedroyc  ...           2021-03-04
# 2    Brendan Walsh  ...           2021-03-04
# 3              NaN  ...           2021-03-04
# 4    Stephen Irwin  ...           2021-03-04
#
#                          Production House  \
# 0               Canal+, Sandrew Metronome
# 1  Film 4, Monumental Pictures, Lionsgate
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#                              Netflix Link  \
# 0  https://www.netflix.com/watch/81415947
# 1  https://www.netflix.com/watch/81041267
# 2  https://www.netflix.com/watch/81305978
# 3  https://www.netflix.com/watch/81336456
# 4  https://www.netflix.com/watch/81078393
#
#                               IMDb Link  \
# 0  https://www.imdb.com/title/tt1139797
# 1  https://www.imdb.com/title/tt4193072
# 2  https://www.imdb.com/title/tt8945942
# 3  https://www.imdb.com/title/tt6132758
# 4  https://www.imdb.com/title/tt2023611
#
#                                              Summary  IMDb Votes  \
# 0  A med student with a supernatural gift tries t...    205926.0
# 1  When nerdy Johanna moves to London, things get...      2838.0
# 2  Trapped in a frozen car during a blizzard, a p...      1720.0
# 3  Upon moving into a new place, a 20-something r...      1147.0
# 4  Inspired by her moms rebellious past and a con...        63.0
#
#                                                Image  \
# 0  https://occ-0-4708-64.1.nflxso.net/dnm/api/v6/...
# 1  https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 2  https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 3  https://occ-0-1489-1490.1.nflxso.net/dnm/api/v...
# 4  https://occ-0-4039-1500.1.nflxso.net/dnm/api/v...
#
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BOWM4NT...
# 1  https://m.media-amazon.com/images/M/MV5BZGUyN2...
# 2  https://m.media-amazon.com/images/M/MV5BODM2MD...
# 3  https://m.media-amazon.com/images/M/MV5BNWRkMz...
# 4  https://m.media-amazon.com/images/M/MV5BODYyNW...
#
#                                   TMDb Trailer Trailer Site
# 0                                          NaN          NaN
# 1  https://www.youtube.com/watch?v=eIbcxPy4okQ      YouTube
# 2  https://www.youtube.com/watch?v=0RvV7TNUlkQ      YouTube
# 3                                          NaN          NaN
# 4                                          NaN          NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# # Title 정규화

# %%
title_before_rg = df['Title'].values.tolist()

# %%
reg_title = []

for i in title_before_rg:
    text = re.sub('[^a-zA-Z0-9~!@#$%^&*()_+`\-\=/.,"\']',' ',i).strip()
    reg_title.append(text)

# %%
genre_list_df = genre_list_df.drop(['Title'],axis=1)

# %%
title_list_df = genre_list_df.copy()

# %%
title_list_df.insert(0, 'Title', reg_title)

# %%
title_list_df.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                  Genre_List  \
# 0  [crime, drama, fantasy, horror, romance]
# 1                                  [comedy]
# 2                         [drama, thriller]
# 3                                   [drama]
# 4                 [animation, short, drama]
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# 3          Series               7.7
# 4           Movie               8.1
#
#                                 Country Availability       Runtime  \
# 0                                           Thailand  < 30 minutes
# 1                                             Canada      1-2 hour
# 2                                             Canada      1-2 hour
# 3                                Belgium,Netherlands  < 30 minutes
# 4  Lithuania,Poland,France,Iceland,Italy,Spain,Gr...      1-2 hour
#
#           Director  ... Netflix Release Date  \
# 0  Tomas Alfredson  ...           2021-03-04
# 1    Coky Giedroyc  ...           2021-03-04
# 2    Brendan Walsh  ...           2021-03-04
# 3              NaN  ...           2021-03-04
# 4    Stephen Irwin  ...           2021-03-04
#
#                          Production House  \
# 0               Canal+, Sandrew Metronome
# 1  Film 4, Monumental Pictures, Lionsgate
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#                              Netflix Link  \
# 0  https://www.netflix.com/watch/81415947
# 1  https://www.netflix.com/watch/81041267
# 2  https://www.netflix.com/watch/81305978
# 3  https://www.netflix.com/watch/81336456
# 4  https://www.netflix.com/watch/81078393
#
#                               IMDb Link  \
# 0  https://www.imdb.com/title/tt1139797
# 1  https://www.imdb.com/title/tt4193072
# 2  https://www.imdb.com/title/tt8945942
# 3  https://www.imdb.com/title/tt6132758
# 4  https://www.imdb.com/title/tt2023611
#
#                                              Summary  IMDb Votes  \
# 0  A med student with a supernatural gift tries t...    205926.0
# 1  When nerdy Johanna moves to London, things get...      2838.0
# 2  Trapped in a frozen car during a blizzard, a p...      1720.0
# 3  Upon moving into a new place, a 20-something r...      1147.0
# 4  Inspired by her moms rebellious past and a con...        63.0
#
#                                                Image  \
# 0  https://occ-0-4708-64.1.nflxso.net/dnm/api/v6/...
# 1  https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 2  https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 3  https://occ-0-1489-1490.1.nflxso.net/dnm/api/v...
# 4  https://occ-0-4039-1500.1.nflxso.net/dnm/api/v...
#
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BOWM4NT...
# 1  https://m.media-amazon.com/images/M/MV5BZGUyN2...
# 2  https://m.media-amazon.com/images/M/MV5BODM2MD...
# 3  https://m.media-amazon.com/images/M/MV5BNWRkMz...
# 4  https://m.media-amazon.com/images/M/MV5BODYyNW...
#
#                                   TMDb Trailer Trailer Site
# 0                                          NaN          NaN
# 1  https://www.youtube.com/watch?v=eIbcxPy4okQ      YouTube
# 2  https://www.youtube.com/watch?v=0RvV7TNUlkQ      YouTube
# 3                                          NaN          NaN
# 4                                          NaN          NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# # Tag 정규화

# %%
# tags_before_rg = df['Tags']
# reg_tags = []

# for i in range(len(tags_before_rg)):
#     try:
#         target = df.iloc[i, 2].lower().split(',')
#         reg_tags.append(target)
# #         if '&' in target:
# #             target.split('&')
            
#     except:
#         reg_tags.append(None)

# %%
tags_before_rg = df['Tags']
reg_tags = []

for i in range(len(tags_before_rg)):
    try:
        target = df.iloc[i, 2].lower().split(',')
        reg_tags.append(target)
            
    except:
        reg_tags.append(None)

# %%
tag_list_df = title_list_df.copy()

# %%
tag_list_df.insert(4, 'Tags_List', reg_tags)

# %%
# str.split() asdasdasdasd
################

# %%
tag_list_df.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                  Genre_List  \
# 0  [crime, drama, fantasy, horror, romance]
# 1                                  [comedy]
# 2                         [drama, thriller]
# 3                                   [drama]
# 4                 [animation, short, drama]
#
#                                                 Tags  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...
# 1       Dramas,Comedies,Films Based on Books,British
# 2                                          Thrillers
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...
#
#                                            Tags_List         Languages  \
# 0  [comedy programmes, romantic tv comedies, horr...  Swedish, Spanish
# 1  [dramas, comedies, films based on books, british]           English
# 2                                        [thrillers]           English
# 3    [tv dramas, romantic tv dramas, dutch tv shows]           Turkish
# 4  [social issue dramas, teen movies, dramas, com...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# 3          Series               7.7
# 4           Movie               8.1
#
#                                 Country Availability       Runtime  ...  \
# 0                                           Thailand  < 30 minutes  ...
# 1                                             Canada      1-2 hour  ...
# 2                                             Canada      1-2 hour  ...
# 3                                Belgium,Netherlands  < 30 minutes  ...
# 4  Lithuania,Poland,France,Iceland,Italy,Spain,Gr...      1-2 hour  ...
#
#   Netflix Release Date                        Production House  \
# 0           2021-03-04               Canal+, Sandrew Metronome
# 1           2021-03-04  Film 4, Monumental Pictures, Lionsgate
# 2           2021-03-04                                     NaN
# 3           2021-03-04                                     NaN
# 4           2021-03-04                                     NaN
#
#                              Netflix Link  \
# 0  https://www.netflix.com/watch/81415947
# 1  https://www.netflix.com/watch/81041267
# 2  https://www.netflix.com/watch/81305978
# 3  https://www.netflix.com/watch/81336456
# 4  https://www.netflix.com/watch/81078393
#
#                               IMDb Link  \
# 0  https://www.imdb.com/title/tt1139797
# 1  https://www.imdb.com/title/tt4193072
# 2  https://www.imdb.com/title/tt8945942
# 3  https://www.imdb.com/title/tt6132758
# 4  https://www.imdb.com/title/tt2023611
#
#                                              Summary  IMDb Votes  \
# 0  A med student with a supernatural gift tries t...    205926.0
# 1  When nerdy Johanna moves to London, things get...      2838.0
# 2  Trapped in a frozen car during a blizzard, a p...      1720.0
# 3  Upon moving into a new place, a 20-something r...      1147.0
# 4  Inspired by her moms rebellious past and a con...        63.0
#
#                                                Image  \
# 0  https://occ-0-4708-64.1.nflxso.net/dnm/api/v6/...
# 1  https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 2  https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 3  https://occ-0-1489-1490.1.nflxso.net/dnm/api/v...
# 4  https://occ-0-4039-1500.1.nflxso.net/dnm/api/v...
#
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BOWM4NT...
# 1  https://m.media-amazon.com/images/M/MV5BZGUyN2...
# 2  https://m.media-amazon.com/images/M/MV5BODM2MD...
# 3  https://m.media-amazon.com/images/M/MV5BNWRkMz...
# 4  https://m.media-amazon.com/images/M/MV5BODYyNW...
#
#                                   TMDb Trailer Trailer Site
# 0                                          NaN          NaN
# 1  https://www.youtube.com/watch?v=eIbcxPy4okQ      YouTube
# 2  https://www.youtube.com/watch?v=0RvV7TNUlkQ      YouTube
# 3                                          NaN          NaN
# 4                                          NaN          NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# # Genre_List에서 Unique 값

# %%
tag_list_df['Title'].count()
# Out:
# 15480

# %%
genre_list = []
for i in range(len(tag_list_df['Genre_List'])):
    try:
        for j in range(len(tag_list_df['Genre_List'][i])):
            if tag_list_df['Genre_List'][i][j] not in genre_list:
                genre_list.append(tag_list_df['Genre_List'][i][j].strip())
    except:
        continue
        
genre_list
# Out:
# ['crime',
#  'drama',
#  'fantasy',
#  'horror',
#  'romance',
#  'comedy',
#  'thriller',
#  'animation',
#  'short',
#  'family',
#  'mystery',
#  'action',
#  'adventure',
#  'sci-fi',
#  'music',
#  'biography',
#  'sport',
#  'war',
#  'history',
#  'documentary',
#  'film-noir',
#  'musical',
#  'game-show',
#  'western',
#  'reality-tv',
#  'talk-show',
#  'news',
#  'adult']

# %%
unique_genre_list = list(set(genre_list))
unique_genre_list
# Out:
# ['music',
#  'war',
#  'history',
#  'adventure',
#  'drama',
#  'family',
#  'adult',
#  'romance',
#  'comedy',
#  'musical',
#  'talk-show',
#  'film-noir',
#  'crime',
#  'reality-tv',
#  'short',
#  'sci-fi',
#  'documentary',
#  'animation',
#  'thriller',
#  'sport',
#  'biography',
#  'horror',
#  'action',
#  'mystery',
#  'western',
#  'game-show',
#  'news',
#  'fantasy']

# %%
single_genre_df = pd.DataFrame(unique_genre_list, columns=['Genre'])
single_genre_df['Count'] = 0
single_genre_df = single_genre_df.set_index('Genre')

# %%
single_genre_df
# Out:
#              Count
# Genre
# music            0
# war              0
# history          0
# adventure        0
# drama            0
# family           0
# adult            0
# romance          0
# comedy           0
# musical          0
# talk-show        0
# film-noir        0
# crime            0
# reality-tv       0
# short            0
# sci-fi           0
# documentary      0
# animation        0
# thriller         0
# sport            0
# biography        0
# horror           0
# action           0
# mystery          0
# western          0
# game-show        0
# news             0
# fantasy          0

# %%
single_genre_df['Count']['fantasy']
# Out:
# 0

# %%
for i in range(len(tag_list_df['Genre_List'])):
    try:
        for j in range(len(tag_list_df['Genre_List'][i])):
            if tag_list_df['Genre_List'][i][j] in unique_genre_list:
                try:
                    single_genre_df['Count'][tag_list_df['Genre_List'][i][j]] += 1
                except:
                    single_genre_df['Count'][tag_list_df['Genre_List'][i][j]] = 0
                    single_genre_df['Count'][tag_list_df['Genre_List'][i][j]] += 1
    except:
        continue

# %%
single_genre_df.sort_values(by='Count',ascending=False)
# Out:
#              Count
# Genre
# drama         6359
# comedy        5077
# action        2810
# thriller      2739
# romance       2445
# crime         1932
# adventure     1809
# animation     1665
# fantasy       1594
# family        1433
# sci-fi        1204
# mystery       1190
# horror        1070
# documentary   1030
# biography      636
# history        527
# music          426
# short          422
# sport          367
# war            330
# musical        228
# reality-tv     191
# western        109
# game-show       52
# talk-show       26
# news            20
# adult           15
# film-noir        2

# %%
single_genre_df.shape
# Out:
# (28, 1)

# %% [markdown]
# # Can One-Hot-Encoding with List ?

# %%
tag_list_df.head(1)
# Out:
#               Title                                   Genre  \
# 0  Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
#
#                                  Genre_List  \
# 0  [crime, drama, fantasy, horror, romance]
#
#                                                 Tags  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...
#
#                                            Tags_List         Languages  \
# 0  [comedy programmes, romantic tv comedies, horr...  Swedish, Spanish
#
#   Series or Movie  Hidden Gem Score Country Availability       Runtime  ...  \
# 0          Series               4.3             Thailand  < 30 minutes  ...
#
#   Netflix Release Date           Production House  \
# 0           2021-03-04  Canal+, Sandrew Metronome
#
#                              Netflix Link  \
# 0  https://www.netflix.com/watch/81415947
#
#                               IMDb Link  \
# 0  https://www.imdb.com/title/tt1139797
#
#                                              Summary  IMDb Votes  \
# 0  A med student with a supernatural gift tries t...    205926.0
#
#                                                Image  \
# 0  https://occ-0-4708-64.1.nflxso.net/dnm/api/v6/...
#
#                                               Poster  TMDb Trailer  \
# 0  https://m.media-amazon.com/images/M/MV5BOWM4NT...           NaN
#
#   Trailer Site
# 0          NaN
#
# [1 rows x 31 columns]

# %%
tag_list_df.columns
# Out:
# Index(['Title', 'Genre', 'Genre_List', 'Tags', 'Tags_List', 'Languages',
#        'Series or Movie', 'Hidden Gem Score', 'Country Availability',
#        'Runtime', 'Director', 'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'Production House', 'Netflix Link', 'IMDb Link',
#        'Summary', 'IMDb Votes', 'Image', 'Poster', 'TMDb Trailer',
#        'Trailer Site'],
#       dtype='object')

# %%
bf_ohe_trial_df = tag_list_df[['Title', 'Genre_List', 'Series or Movie']]
bf_ohe_trial_df.head()
# Out:
#                  Title                                Genre_List  \
# 0     Lets Fight Ghost  [crime, drama, fantasy, horror, romance]
# 1  HOW TO BUILD A GIRL                                  [comedy]
# 2           Centigrade                         [drama, thriller]
# 3                ANNE+                                   [drama]
# 4                Moxie                 [animation, short, drama]
#
#   Series or Movie
# 0          Series
# 1           Movie
# 2           Movie
# 3          Series
# 4           Movie

# %%
at_ohe_trial_df = pd.get_dummies(data=bf_ohe_trial_df, columns=['Series or Movie'])
at_ohe_trial_df.head()
# Out:
#                  Title                                Genre_List  \
# 0     Lets Fight Ghost  [crime, drama, fantasy, horror, romance]
# 1  HOW TO BUILD A GIRL                                  [comedy]
# 2           Centigrade                         [drama, thriller]
# 3                ANNE+                                   [drama]
# 4                Moxie                 [animation, short, drama]
#
#    Series or Movie_Movie  Series or Movie_Series
# 0                      0                       1
# 1                      1                       0
# 2                      1                       0
# 3                      0                       1
# 4                      1                       0

# %%
at_ohe_trial_df['Genre_List'][0].str
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-9f97792fa237> in <module>
# ----> 1 at_ohe_trial_df['Genre_List'][0].str
#
# AttributeError: 'list' object has no attribute 'str'

# %%
at_ohe_trial_df['Genre_List'] = at_ohe_trial_df['Genre_List'].map(lambda x: x.str.split())

# %%
# at_ohe_trial_df = pd.get_dummies(data=at_ohe_trial_df, columns=['Genre_List'])

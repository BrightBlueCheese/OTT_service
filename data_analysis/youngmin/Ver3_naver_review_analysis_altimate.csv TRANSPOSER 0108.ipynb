# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import re
from wordcloud import WordCloud
import random # 워드 클라우드를 위해서 필요합니다..

import matplotlib.font_manager as fm

# %%
df = pd.read_csv('../data/Ver3_naver_review_analysis_altimate.csv')

# %%
df
# Out:
#           genre  average_male  average_female  average_10s  average_20s  \
# 0         drama          8.48            8.53         8.86         8.53
# 1        comedy          8.73            8.70         9.00         8.80
# 2        action          8.39            8.53         8.77         8.51
# 3      thriller          8.41            8.43         8.74         8.46
# 4       romance          8.61            8.46         8.96         8.59
# 5         crime          8.46            8.56         8.82         8.54
# 6     adventure          8.48            8.59         8.93         8.63
# 7     animation          8.83            8.76         9.28         8.91
# 8       fantasy          8.60            8.61         9.05         8.66
# 9        family          8.73            8.74         9.10         8.84
# 10       sci_fi          8.21            8.35         8.72         8.34
# 11      mystery          8.20            8.26         8.53         8.26
# ...

# %%
transposed_df = df.T
transposed_df
# Out:
#                    0       1       2         3        4      5          6   \
# genre           drama  comedy  action  thriller  romance  crime  adventure
# average_male     8.48    8.73    8.39      8.41     8.61   8.46       8.48
# average_female   8.53     8.7    8.53      8.43     8.46   8.56       8.59
# average_10s      8.86     9.0    8.77      8.74     8.96   8.82       8.93
# average_20s      8.53     8.8    8.51      8.46     8.59   8.54       8.63
# average_30s      8.41    8.64    8.37      8.34     8.38   8.43       8.43
# average_40s      8.49    8.59    8.41      8.34      8.4   8.48       8.39
# average_50_up     8.5    8.57    8.42      8.38     8.39   8.47       8.48
#
#                        7        8       9   ...      12           13  \
# genre           animation  fantasy  family  ...  horror  documentary
# average_male         8.83      8.6    8.73  ...    8.24         9.46
# average_female       8.76     8.61    8.74  ...    8.22         9.57
# ...

# %%
transposed_df.columns = transposed_df.iloc[0]

# %%
transposed_df = transposed_df.drop(['genre'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-2096c0643475> in <module>
# ----> 1 transposed_df = transposed_df.drop(['genre'])
#       2 transposed_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
transposed_df
# Out:
# genre          drama comedy action thriller romance crime adventure animation  \
# average_male    8.48   8.73   8.39     8.41    8.61  8.46      8.48      8.83
# average_female  8.53    8.7   8.53     8.43    8.46  8.56      8.59      8.76
# average_10s     8.86    9.0   8.77     8.74    8.96  8.82      8.93      9.28
# average_20s     8.53    8.8   8.51     8.46    8.59  8.54      8.63      8.91
# average_30s     8.41   8.64   8.37     8.34    8.38  8.43      8.43      8.72
# average_40s     8.49   8.59   8.41     8.34     8.4  8.48      8.39      8.67
# average_50_up    8.5   8.57   8.42     8.38    8.39  8.47      8.48      8.81
#
# genre          fantasy family  ... horror documentary biography history music  \
# average_male       8.6   8.73  ...   8.24        9.46      8.71    8.39  8.33
# average_female    8.61   8.74  ...   8.22        9.57      8.84    8.55  8.35
# average_10s       9.05    9.1  ...   8.46        9.29      8.94    8.68  8.17
# ...

# %%
transposed_df.to_csv('../data/T_droped_Ver3_naver_review_analysis_altimate.csv', sep=',', encoding='utf-8-sig')

# %%
# df.T.to_csv('../data/T_Ver3_naver_review_analysis_altimate.csv', sep=',', encoding='utf-8-sig')

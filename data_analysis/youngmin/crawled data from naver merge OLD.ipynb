# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
from datetime import datetime

from sklearn import preprocessing

# %%
df1 = pd.read_csv('../code/soryeongk/crawled.csv')
df2 = pd.read_csv('../code/soryeongk/temp_df.csv')

# %%
crawled_df = df1.copy()
age_pct_df = df2.copy()

# %%
crawled_df
# Out:
#         code         korean_title num_of_audience  \
# 0     203096             걸스 오브 막시             NaN
# 1      17997                  첨밀밀             NaN
# 2     181925                  클로젯             387
# 3     195979          비밀경찰: 랍스터 캅             NaN
# 4     138113                매직 아워             NaN
# ...      ...                  ...             ...
# 1819   72043               쓰리 데이즈             NaN
# 1820   77566         브레이킹 던 part2             NaN
# 1821   38227           첫 키스만 50번째             177
# 1822   74567         브레이킹 던 part1             NaN
# 1823   38572  완벽한 그녀에게 딱 한가지 없는 것             NaN
#
#                               key_review  score_male  score_female  \
# 0                                    NaN         NaN           NaN
# 1                                    NaN         NaN           NaN
# 2      이 영화는 20대 여성이 좋아하는 연기가 뛰어난 영화입니다.        7.93          8.41
# 3                                    NaN         NaN           NaN
# ...

# %%
print(len(crawled_df['code'].unique()))
print(len(age_pct_df['code'].unique()))
# Out:
# 1824
# 1824

# %%
age_pct_df
# Out:
#         code                       num_per_ages
# 0     203096                                 []
# 1      17997                                 []
# 2     181925  ['2%', '44%', '30%', '15%', '9%']
# 3     195979                                 []
# 4     138113                                 []
# ...      ...                                ...
# 1819   72043                                 []
# 1820   77566                                 []
# 1821   38227   ['5%', '68%', '15%', '7%', '5%']
# 1822   74567                                 []
# 1823   38572                                 []
#
# [1824 rows x 2 columns]

# %%
crawling_audience_review_modifided_df = pd.merge(crawled_df, age_pct_df, how='inner', on='code')

# %%
# crawling_audience_review_modifided_df.to_csv('../data/crawling_audience_review_modified.csv', sep=',', encoding='utf-8-sig')
